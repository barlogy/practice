# %% [markdown]
# # Игра угадай число

# %%
from game_v2 import score_game
from game_v2 import random_predict
from game_v2 import binary_search_predict
from game_v2 import compare_algorithms

# %% [markdown]
# ## Угадываем рандомно

# %%
score_game(random_predict)
# Out:
# Алгоритм 'random_predict' угадывает число в среднем за: 95 попыток
# 95

# %% [markdown]
# ## Угадываем с использованием бинарного поиска

# %%
score_game(binary_search_predict)
# Out:
# Алгоритм 'binary_search_predict' угадывает число в среднем за: 5 попыток
# 5

# %% [markdown]
# ## Сравнение алгоритмов угадывания

# %%
compare_algorithms()
# Out:
# Алгоритм 'random_predict' угадывает число в среднем за: 100 попыток
# Алгоритм 'binary_search_predict' угадывает число в среднем за: 6 попыток
# ===============================================================================
# Бинарный поиск эффективнее случайного в 16.7 раз
